# %%
# %matplotlib inline

from tiptop.tiptop import *
import torch
rc("text", usetex=False)

# %%
import sys
sys.path.insert(0, "/home/frossi/dev/TipTorch")
sys.path.insert(0, "/home/frossi/dev/TipTorch/PSF_models")

# %%
import os
os.chdir("/home/frossi/dev/TIPTOP/")

# %%
overallSimulation("tiptop/perfTest", "SOUL", 'tiptop/perfTest', 'testSOUL', doPlot=True, doConvolve=True, backendHO='p3', gpuIndex=0, verbose=True, savePSDs=True, saveJson=True)

# %%
overallSimulation("tiptop/perfTest", "SOUL", 'tiptop/perfTest', 'testSOUL', doPlot=True, doConvolve=True, backendHO='tiptorch', gpuIndex=0, verbose=True, savePSDs=True, saveJson=True, tiptorch_device=torch.device('cuda:0'))
