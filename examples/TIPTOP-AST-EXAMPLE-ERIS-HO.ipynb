# %%
import time
import datetime
#%matplotlib inline
from tiptop.tiptop import *
rc("text", usetex=False)

import os
os.chdir('/Users/guido/GitHub/TIPTOP/')
# Out:
# Cupy import failed. P3 will fall back to CPU use.
# ---->    nphHO = [200, 200]
# Cupy import failed. MASTSEL will fall back to CPU use.
# Cupy import failed. SEEING will fall back to CPU use.

# %%
scipy.__version__
# Out:
# '1.16.0'

# %%
sr, fw, ee, simul = hoAsterismSelection("TestERISHO", "tiptop/astTest", "ERISastHO", 
                                       'tiptop/astTest', 'testERISHO', 
                                       doPlot=False, verbose=True, progressStatus=True)
# Out:
# LO part is not present
# HO Asterism mode: SingleHO
# Number of HO configurations: 7
# Processing HO configuration 1/7
# Configured HO asterism 0 with 1 stars
# Temporary config file: tiptop/astTest/ERISastHO_temp_0.ini
#   HO Star 0: Zenith=0.00, Azimuth=0.00, Wavelength=750nm, Photons=200.0
# Using temporary path: tiptop/astTest, file: ERISastHO_temp_0
# ******** HO PSD science and NGSs directions
# Warning: No information about the tip-tilt star can be retrieved
# ---->    nphHO = [200.0]
# extra error in nm RMS:  0
# extra error spatial frequency exponent:  -2
# extra error in nm RMS (LO):  0
# extra error spatial frequency exponent (LO):  -2
# Required time for total calculation (ms)	 : 169.638872
# Required time for AO system model init (ms)	 : 1.208067
# Required time for frequency domain init (ms)	 : 25.138855
# Required time for atmosphere nodel init (ms)	 : 0.044107
# Required time for final PSD calculation (ms)	 : 134.431124
# Required time for WFS reconstructors init (ms)	 : 0.752926
# Required time for controller instantiation (ms)	 : 7.210016
# Required time for fitting PSD calculation (ms)	 : 0.712872
# Required time for aliasing PSD calculation (ms)	 : 129.338980
# Required time for noise PSD calculation (ms)	 : 0.077724
# Required time for ST PSD calculation (ms)	 : 0.285149
# PSD step: 0.04113570627596063
# PSD freq range: 10.530740806645921
# PSD shape: (1, 256, 256)
# oversampling: 1
# sensor_science.PixelScale: 14
# ******** HO PSF
# SR(@ 1650 nm)        : 0.91192
# FWHM(@ 1650 nm) [mas]: 44.109
# Calculating profile with PSF normalized to total = 1
# HO_res [nm]: [79.742]
# EE is computed for a radius of  50  mas
# Config 0: SR=0.8947, FWHM=44.11mas, EE=0.7362, HO_res=79.7nm
# Config 0: SR=0.8947, FWHM=44.11mas, EE=0.7362, HO_res=79.7nm
# Processing HO configuration 2/7
# Configured HO asterism 1 with 1 stars
# Temporary config file: tiptop/astTest/ERISastHO_temp_1.ini
#   HO Star 0: Zenith=5.00, Azimuth=90.00, Wavelength=750nm, Photons=200.0
# Using temporary path: tiptop/astTest, file: ERISastHO_temp_1
# ******** HO PSD science and NGSs directions
# Warning: No information about the tip-tilt star can be retrieved
# ---->    nphHO = [200.0]
# extra error in nm RMS:  0
# extra error spatial frequency exponent:  -2
# extra error in nm RMS (LO):  0
# extra error spatial frequency exponent (LO):  -2
# Required time for total calculation (ms)	 : 146.646023
# Required time for AO system model init (ms)	 : 1.221895
# Required time for frequency domain init (ms)	 : 24.855137
# Required time for atmosphere nodel init (ms)	 : 0.033140
# Required time for final PSD calculation (ms)	 : 112.616777
# Required time for WFS reconstructors init (ms)	 : 0.826836
# Required time for controller instantiation (ms)	 : 7.093906
# Required time for fitting PSD calculation (ms)	 : 0.648975
# Required time for aliasing PSD calculation (ms)	 : 105.648041
# Required time for noise PSD calculation (ms)	 : 0.088215
# Required time for ST PSD calculation (ms)	 : 2.586126
# PSD step: 0.04113570627596063
# PSD freq range: 10.530740806645921
# PSD shape: (1, 256, 256)
# oversampling: 1
# sensor_science.PixelScale: 14
# ******** HO PSF
# SR(@ 1650 nm)        : 0.63932
# FWHM(@ 1650 nm) [mas]: 44.467
# Calculating profile with PSF normalized to total = 1
# HO_res [nm]: [175.64]
# EE is computed for a radius of  50  mas
# Config 1: SR=0.6356, FWHM=44.47mas, EE=0.5489, HO_res=175.6nm
# Config 1: SR=0.6356, FWHM=44.47mas, EE=0.5489, HO_res=175.6nm
# Processing HO configuration 3/7
# Configured HO asterism 2 with 1 stars
# Temporary config file: tiptop/astTest/ERISastHO_temp_2.ini
#   HO Star 0: Zenith=10.00, Azimuth=180.00, Wavelength=750nm, Photons=200.0
# Using temporary path: tiptop/astTest, file: ERISastHO_temp_2
# ******** HO PSD science and NGSs directions
# Warning: No information about the tip-tilt star can be retrieved
# ---->    nphHO = [200.0]
# extra error in nm RMS:  0
# extra error spatial frequency exponent:  -2
# extra error in nm RMS (LO):  0
# extra error spatial frequency exponent (LO):  -2
# Required time for total calculation (ms)	 : 143.195152
# Required time for AO system model init (ms)	 : 0.761747
# Required time for frequency domain init (ms)	 : 23.183107
# Required time for atmosphere nodel init (ms)	 : 0.038862
# Required time for final PSD calculation (ms)	 : 111.579895
# Required time for WFS reconstructors init (ms)	 : 0.787258
# Required time for controller instantiation (ms)	 : 6.515980
# Required time for fitting PSD calculation (ms)	 : 0.579119
# Required time for aliasing PSD calculation (ms)	 : 104.468107
# Required time for noise PSD calculation (ms)	 : 0.072956
# Required time for ST PSD calculation (ms)	 : 2.243042
# PSD step: 0.04113570627596063
# PSD freq range: 10.530740806645921
# PSD shape: (1, 256, 256)
# oversampling: 1
# sensor_science.PixelScale: 14
# ******** HO PSF
# SR(@ 1650 nm)        : 0.36823
# FWHM(@ 1650 nm) [mas]: 45.743
# Calculating profile with PSF normalized to total = 1
# HO_res [nm]: [262.48]
# EE is computed for a radius of  50  mas
# Config 2: SR=0.3796, FWHM=45.74mas, EE=0.3718, HO_res=262.5nm
# Config 2: SR=0.3796, FWHM=45.74mas, EE=0.3718, HO_res=262.5nm
# Processing HO configuration 4/7
# Configured HO asterism 3 with 1 stars
# Temporary config file: tiptop/astTest/ERISastHO_temp_3.ini
#   HO Star 0: Zenith=15.00, Azimuth=270.00, Wavelength=750nm, Photons=200.0
# Using temporary path: tiptop/astTest, file: ERISastHO_temp_3
# ******** HO PSD science and NGSs directions
# Warning: No information about the tip-tilt star can be retrieved
# ---->    nphHO = [200.0]
# extra error in nm RMS:  0
# extra error spatial frequency exponent:  -2
# extra error in nm RMS (LO):  0
# extra error spatial frequency exponent (LO):  -2
# Required time for total calculation (ms)	 : 170.476913
# Required time for AO system model init (ms)	 : 0.898123
# Required time for frequency domain init (ms)	 : 22.603035
# Required time for atmosphere nodel init (ms)	 : 0.036955
# Required time for final PSD calculation (ms)	 : 138.257980
# Required time for WFS reconstructors init (ms)	 : 0.826120
# Required time for controller instantiation (ms)	 : 7.194996
# Required time for fitting PSD calculation (ms)	 : 0.739813
# Required time for aliasing PSD calculation (ms)	 : 131.462097
# Required time for noise PSD calculation (ms)	 : 0.079870
# Required time for ST PSD calculation (ms)	 : 2.194166
# PSD step: 0.04113570627596063
# PSD freq range: 10.530740806645921
# PSD shape: (1, 256, 256)
# oversampling: 1
# sensor_science.PixelScale: 14
# ******** HO PSF
# SR(@ 1650 nm)        : 0.20473
# FWHM(@ 1650 nm) [mas]: 47.813
# Calculating profile with PSF normalized to total = 1
# HO_res [nm]: [330.724]
# EE is computed for a radius of  50  mas
# Config 3: SR=0.2260, FWHM=47.83mas, EE=0.2671, HO_res=330.7nm
# Config 3: SR=0.2260, FWHM=47.83mas, EE=0.2671, HO_res=330.7nm
# Processing HO configuration 5/7
# Configured HO asterism 4 with 1 stars
# Temporary config file: tiptop/astTest/ERISastHO_temp_4.ini
#   HO Star 0: Zenith=0.00, Azimuth=0.00, Wavelength=750nm, Photons=50.0
# Using temporary path: tiptop/astTest, file: ERISastHO_temp_4
# ******** HO PSD science and NGSs directions
# Warning: No information about the tip-tilt star can be retrieved
# ---->    nphHO = [50.0]
# extra error in nm RMS:  0
# extra error spatial frequency exponent:  -2
# extra error in nm RMS (LO):  0
# extra error spatial frequency exponent (LO):  -2
# Required time for total calculation (ms)	 : 156.785965
# Required time for AO system model init (ms)	 : 1.131058
# Required time for frequency domain init (ms)	 : 22.187233
# Required time for atmosphere nodel init (ms)	 : 0.041962
# Required time for final PSD calculation (ms)	 : 124.198198
# Required time for WFS reconstructors init (ms)	 : 0.996828
# Required time for controller instantiation (ms)	 : 7.520914
# Required time for fitting PSD calculation (ms)	 : 0.784874
# Required time for aliasing PSD calculation (ms)	 : 118.844032
# Required time for noise PSD calculation (ms)	 : 0.087023
# Required time for ST PSD calculation (ms)	 : 0.241995
# PSD step: 0.04113570627596063
# PSD freq range: 10.530740806645921
# PSD shape: (1, 256, 256)
# oversampling: 1
# sensor_science.PixelScale: 14
# ******** HO PSF
# SR(@ 1650 nm)        : 0.89963
# FWHM(@ 1650 nm) [mas]: 44.131
# Calculating profile with PSF normalized to total = 1
# HO_res [nm]: [85.404]
# EE is computed for a radius of  50  mas
# Config 4: SR=0.8836, FWHM=44.13mas, EE=0.7287, HO_res=85.4nm
# Config 4: SR=0.8836, FWHM=44.13mas, EE=0.7287, HO_res=85.4nm
# Processing HO configuration 6/7
# Configured HO asterism 5 with 1 stars
# Temporary config file: tiptop/astTest/ERISastHO_temp_5.ini
#   HO Star 0: Zenith=0.00, Azimuth=0.00, Wavelength=750nm, Photons=10.0
# Using temporary path: tiptop/astTest, file: ERISastHO_temp_5
# ******** HO PSD science and NGSs directions
# Warning: No information about the tip-tilt star can be retrieved
# ---->    nphHO = [10.0]
# extra error in nm RMS:  0
# extra error spatial frequency exponent:  -2
# extra error in nm RMS (LO):  0
# extra error spatial frequency exponent (LO):  -2
# Required time for total calculation (ms)	 : 193.979025
# Required time for AO system model init (ms)	 : 1.034021
# Required time for frequency domain init (ms)	 : 26.826859
# Required time for atmosphere nodel init (ms)	 : 0.038147
# Required time for final PSD calculation (ms)	 : 156.692028
# Required time for WFS reconstructors init (ms)	 : 0.663042
# Required time for controller instantiation (ms)	 : 8.023977
# Required time for fitting PSD calculation (ms)	 : 0.591278
# Required time for aliasing PSD calculation (ms)	 : 152.561903
# Required time for noise PSD calculation (ms)	 : 0.078917
# Required time for ST PSD calculation (ms)	 : 0.190973
# PSD step: 0.04113570627596063
# PSD freq range: 10.530740806645921
# PSD shape: (1, 256, 256)
# oversampling: 1
# sensor_science.PixelScale: 14
# ******** HO PSF
# SR(@ 1650 nm)        : 0.81563
# FWHM(@ 1650 nm) [mas]: 44.295
# Calculating profile with PSF normalized to total = 1
# HO_res [nm]: [118.55]
# EE is computed for a radius of  50  mas
# Config 5: SR=0.8071, FWHM=44.29mas, EE=0.6771, HO_res=118.5nm
# Config 5: SR=0.8071, FWHM=44.29mas, EE=0.6771, HO_res=118.5nm
# Processing HO configuration 7/7
# Configured HO asterism 6 with 1 stars
# Temporary config file: tiptop/astTest/ERISastHO_temp_6.ini
#   HO Star 0: Zenith=0.00, Azimuth=0.00, Wavelength=750nm, Photons=5.0
# Using temporary path: tiptop/astTest, file: ERISastHO_temp_6
# ******** HO PSD science and NGSs directions
# Warning: No information about the tip-tilt star can be retrieved
# ---->    nphHO = [5.0]
# extra error in nm RMS:  0
# extra error spatial frequency exponent:  -2
# extra error in nm RMS (LO):  0
# extra error spatial frequency exponent (LO):  -2
# Required time for total calculation (ms)	 : 149.285793
# Required time for AO system model init (ms)	 : 1.055002
# Required time for frequency domain init (ms)	 : 22.351980
# Required time for atmosphere nodel init (ms)	 : 0.036001
# Required time for final PSD calculation (ms)	 : 117.381811
# Required time for WFS reconstructors init (ms)	 : 0.813723
# Required time for controller instantiation (ms)	 : 6.624937
# Required time for fitting PSD calculation (ms)	 : 0.681162
# Required time for aliasing PSD calculation (ms)	 : 112.205982
# Required time for noise PSD calculation (ms)	 : 0.092268
# Required time for ST PSD calculation (ms)	 : 0.246048
# PSD step: 0.04113570627596063
# PSD freq range: 10.530740806645921
# PSD shape: (1, 256, 256)
# oversampling: 1
# sensor_science.PixelScale: 14
# ******** HO PSF
# SR(@ 1650 nm)        : 0.67893
# FWHM(@ 1650 nm) [mas]: 44.611
# Calculating profile with PSF normalized to total = 1
# HO_res [nm]: [163.416]
# EE is computed for a radius of  50  mas
# Config 6: SR=0.6816, FWHM=44.61mas, EE=0.5902, HO_res=163.4nm
# Config 6: SR=0.6816, FWHM=44.61mas, EE=0.5902, HO_res=163.4nm

# %%
print("Results HO Asterism Selection:")
print(f"Number of configurations: {len(sr)}")
for i, (sr_val, fw_val, ee_val) in enumerate(zip(sr, fw, ee)):
    print(f"Config {i}: SR={sr_val[0]:.4f}, FWHM={fw_val[0]:.2f}mas, EE={ee_val[0]:.4f}")
# Out:
# Results HO Asterism Selection:
# Number of configurations: 7
# Config 0: SR=0.8947, FWHM=44.11mas, EE=0.7362
# Config 1: SR=0.6356, FWHM=44.47mas, EE=0.5489
# Config 2: SR=0.3796, FWHM=45.74mas, EE=0.3718
# Config 3: SR=0.2260, FWHM=47.83mas, EE=0.2671
# Config 4: SR=0.8836, FWHM=44.13mas, EE=0.7287
# Config 5: SR=0.8071, FWHM=44.29mas, EE=0.6771
# Config 6: SR=0.6816, FWHM=44.61mas, EE=0.5902

# %%
simul.plotHoResults()
# Out:
# Best configuration (highest SR): 0
#   Strehl Ratio: 0.8947
#   FWHM: 44.11 mas
#   EE: 0.7362
#   HO Residual: 79.7 nm RMS

# %%
single_result = simul.computeHoAsterisms(eeRadiusInMas=50, index=0)
print("Single configuration result:")
print(single_result[0])
# Out:
# Processing HO configuration 1/1
# Configured HO asterism 0 with 1 stars
# Temporary config file: tiptop/astTest/ERISastHO_temp_0.ini
#   HO Star 0: Zenith=0.00, Azimuth=0.00, Wavelength=750nm, Photons=200.0
# Using temporary path: tiptop/astTest, file: ERISastHO_temp_0
# ******** HO PSD science and NGSs directions
# Warning: No information about the tip-tilt star can be retrieved
# ---->    nphHO = [200.0]
# extra error in nm RMS:  0
# extra error spatial frequency exponent:  -2
# extra error in nm RMS (LO):  0
# extra error spatial frequency exponent (LO):  -2
# Required time for total calculation (ms)	 : 181.033134
# Required time for AO system model init (ms)	 : 1.821041
# Required time for frequency domain init (ms)	 : 33.524990
# Required time for atmosphere nodel init (ms)	 : 0.048876
# Required time for final PSD calculation (ms)	 : 136.961937
# Required time for WFS reconstructors init (ms)	 : 1.270056
# Required time for controller instantiation (ms)	 : 7.970095
# Required time for fitting PSD calculation (ms)	 : 0.551939
# Required time for aliasing PSD calculation (ms)	 : 132.860184
# Required time for noise PSD calculation (ms)	 : 0.093937
# Required time for ST PSD calculation (ms)	 : 0.164986
# PSD step: 0.04113570627596063
# PSD freq range: 10.530740806645921
# PSD shape: (1, 256, 256)
# oversampling: 1
# sensor_science.PixelScale: 14
# ******** HO PSF
# SR(@ 1650 nm)        : 0.91192
# FWHM(@ 1650 nm) [mas]: 44.109
# Calculating profile with PSF normalized to total = 1
# HO_res [nm]: [79.742]
# EE is computed for a radius of  50  mas
# Config 0: SR=0.8947, FWHM=44.11mas, EE=0.7362, HO_res=79.7nm
# Config 0: SR=0.8947, FWHM=44.11mas, EE=0.7362, HO_res=79.7nm
# Risultato configurazione singola:
# HoAsterismProperties(index=0, ho_stars=[HoStar(zenith=np.float64(0.0), azimuth=np.float64(0.0), wavelength=np.float64(7.5e-07), photons=np.float64(200.0))], strehl_ratio=np.float64(0.89471), fwhm=np.float64(44.10883993317781), encircled_energy=0.7361942399095909, ho_residual=np.float64(79.74228732123014))

# %%
try:
    simul.reloadHoResults()
    print("Results reloaded successfully")
except:
    print("No previous results found")
# Out:
# Results reloaded successfully
